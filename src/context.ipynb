# %%
import pandas as pd

pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199

# %%
from demographic_filtering import demographic_filtering

demographic_filtering()[['title', 'weighted_rating', 'vote_average', 'vote_count']].head(10)
# Out:
#                                               title  weighted_rating  \
# 1881                       The Shawshank Redemption         8.059258
# 662                                      Fight Club         7.939256
# 65                                  The Dark Knight         7.920020
# 3232                                   Pulp Fiction         7.904645
# 96                                        Inception         7.863239
# 3337                                  The Godfather         7.851236
# 95                                     Interstellar         7.809479
# 809                                    Forrest Gump         7.803188
# 329   The Lord of the Rings: The Return of the King         7.727243
# 1990                        The Empire Strikes Back         7.697884
#
#       vote_average  vote_count
# 1881           8.5        8205
# 662            8.3        9413
# 65             8.2       12002
# 3232           8.3        8428
# 96             8.1       13752
# ...

# %%
from load_data import load_data

movies = load_data()
title_to_index = pd.Series(movies.index, index=movies['title']).drop_duplicates()
idx_dark_knight_rises = title_to_index['The Dark Knight Rises']
idx_inception = title_to_index['Inception']

movies.iloc[[idx_dark_knight_rises, idx_inception]].head()[['title', 'overview']]
# Out:
#                     title  \
# 3   The Dark Knight Rises
# 96              Inception
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                         overview
# 3   Following the death of District Attorney Harvey Dent, Batman assumes responsibility for Dent's crimes to protect the late attorney's reputation and is subsequently hunted by the Gotham City Police Department. Eight years later, Batman encounters the mysterious Selina Kyle and the villainous Bane, a new terrorist leader who overwhelms Gotham's finest. The Dark Knight resurfaces to protect a city that has branded him an enemy.
# ...

# %%
from content_based_filtering import tf_idf_filtering

tf_idf_filtering('The Dark Knight Rises')
# Out:
# [nltk_data] Downloading package stopwords to /home/yonguk/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                         title  \
# 65                            The Dark Knight
# 299                            Batman Forever
# 428                            Batman Returns
# 1359                                   Batman
# 3854  Batman: The Dark Knight Returns, Part 2
# 119                             Batman Begins
# 2507                                Slow Burn
# 9          Batman v Superman: Dawn of Justice
# 1181                                      JFK
# 210                            Batman & Robin
#
# ...

# %%
tf_idf_filtering('Inception')
# Out:
#                                    title  \
# 2897                              Cypher
# 134   Mission: Impossible - Rogue Nation
# 1930                          Stone Cold
# 914                 Central Intelligence
# 1683                     Pitch Perfect 2
# 1248                      At First Sight
# 1512               A History of Violence
# 2389                         Renaissance
# 1803                      Blood and Wine
# 1267                              Duplex
#
# ...

# %%
from content_based_filtering import w2v_tf_idf_filtering

w2v_tf_idf_filtering('The Dark Knight Rises')
# Out:
#                              title  \
# 65                 The Dark Knight
# 299                 Batman Forever
# 3819                      Defendor
# 1359                        Batman
# 1412                    Predator 2
# 1830                    Ride Along
# 119                  Batman Begins
# 238   Teenage Mutant Ninja Turtles
# 1742                Brick Mansions
# 428                 Batman Returns
#
# ...

# %%
w2v_tf_idf_filtering('Inception')
# Out:
#                           title  \
# 493            A Beautiful Mind
# 1892                 The Losers
# 125         The Matrix Reloaded
# 3197             Flame & Citron
# 599                  Hart's War
# 2026                    The Net
# 2080  Tinker Tailor Soldier Spy
# 3474                  The Words
# 115                     Hancock
# 1528                   Criminal
#
# ...

# %%
from content_based_filtering import sentence_filtering

sentence_filtering('The Dark Knight Rises')
# Out:
# querying OpenAI API: 100%|██████████| 300/300 [01:18<00:00,  3.84it/s]
#                                         title  \
# 65                            The Dark Knight
# 299                            Batman Forever
# 1359                                   Batman
# 428                            Batman Returns
# 119                             Batman Begins
# 9          Batman v Superman: Dawn of Justice
# 210                            Batman & Robin
# 3854  Batman: The Dark Knight Returns, Part 2
# 901             Robin Hood: Prince of Thieves
# 163                                  Watchmen
#
# ...

# %%
sentence_filtering('Inception')
# Out:
# querying OpenAI API: 100%|██████████| 300/300 [01:24<00:00,  3.54it/s]
#                             title  \
# 1434                       Parker
# 2897                       Cypher
# 3433                     The East
# 1799                 Original Sin
# 2583             The November Man
# 1528                     Criminal
# 1851              Nothing to Lose
# 1937                King's Ransom
# 2448                  Wall Street
# 1259  Memoirs of an Invisible Man
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           overview  \
# ...
